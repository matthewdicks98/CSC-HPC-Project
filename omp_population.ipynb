# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Population Experiments

# %%
omp_fitness = pd.read_csv("Results/omp_fitness_population.txt")
omp_fitness[' elapsed/gen_count'] = omp_fitness[' elapsed/gen_count']*1000

omp_breeding = pd.read_csv("Results/omp_breeding_population.txt")
omp_breeding[' elapsed/gen_count'] = omp_breeding[' elapsed/gen_count']*1000

omp_crossover = pd.read_csv("Results/omp_crossover_population.txt")
omp_crossover[' elapsed/gen_count'] = omp_crossover[' elapsed/gen_count']*1000

# %%
omp_fitness
# Out:
#    cores   pop_size   num_particles   final_fitness   gen_count   elapsed  \
# 0     32       2000              50   244152.118286         609    97.203
# 1     32       3000              50   235977.279801         435   114.924
# 2     32       5000              50   264586.118397         575   229.578
# 3     32       7000              50   240283.753423         564   324.364
# 4     32      10000              50   252325.086525         430   401.147
# 5     32      15000              50   272927.130966         965  1247.720
#
#     elapsed/gen_count
# 0             159.611
# 1             264.193
# 2             399.265
# 3             575.113
# 4             932.901
# 5            1292.974

# %%
omp_breeding
# Out:
#    cores   pop_size   num_particles   final_fitness   gen_count   elapsed  \
# 0     32       2000              50   240173.654202         522    86.868
# 1     32       3000              50   252324.163178         452   109.308
# 2     32       5000              50   264751.878567         679   282.127
# 3     32       7000              50   260665.501205         685   403.307
# 4     32      10000              50   281099.316005         836   762.275
# 5     32      15000              50   264531.058548         433   610.684
# 6     32      30000              50   260550.838522         404  1167.282
#
#     elapsed/gen_count
# 0             166.413
# 1             241.831
# 2             415.504
# 3             588.770
# 4             911.812
# 5            1410.355
# 6            2889.312

# %%
omp_crossover
# Out:
#    cores   pop_size   num_particles   final_fitness   gen_count   elapsed  \
# 0     32       2000              50   248457.446855         570    97.097
# 1     32       3000              50   240008.862379         531   145.871
# 2     32       5000              50   223881.786527         314   140.024
# 3     32       7000              50   264641.654047         588   353.226
# 4     32      10000              50   281320.952501         447   370.428
# 5     32      15000              50   256467.279941         359   544.864
# 6     32      30000              50   252325.560065         370  1084.852
#
#     elapsed/gen_count
# 0             170.346
# 1             274.710
# 2             445.935
# 3             600.724
# 4             828.698
# 5            1517.728
# 6            2932.032

# %%
plt.figure(figsize=(9,7))
plt.grid(alpha=0.15)
plt.minorticks_on()
plt.grid(which='minor', color='beige', alpha=0.25)
plt.plot(omp_fitness[' pop_size'], omp_fitness[' elapsed/gen_count'],marker='o', color="forestgreen")
plt.plot(omp_breeding[' pop_size'],omp_breeding[' elapsed/gen_count'],marker='o', color="cornflowerblue")
plt.plot(omp_crossover[' pop_size'],omp_crossover[' elapsed/gen_count'],marker='o', color="violet")
plt.legend(['fitness','fitness and breeding','fitness and breeding and crossover'])
plt.ylabel('Time per 1000 generations (μs)')
plt.xlabel('Population Size')
# Out:
# Text(0.5, 0, 'Population Size')
