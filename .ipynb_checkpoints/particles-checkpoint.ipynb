# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## comapring number of particles

# %%
omp_particles = pd.read_csv("Results/omp_crossover/omp_crossover_particles.txt")
omp_particles[' elapsed/gen_count'] = omp_particles[' elapsed/gen_count']*1000

mpi_particles = pd.read_csv("Results/mpi/mpi_particles.txt")
mpi_particles[' elapsed/gen_count'] = mpi_particles[' elapsed/gen_count']*1000

ser_particles = pd.read_csv("Results/serial/ser_particles.txt")
ser_particles[' elapsed/gen_count'] = ser_particles[' elapsed/gen_count']*1000


laptop_omp_particles = pd.read_csv("Results/laptop/omp_crossover/omp_crossover_particles.txt")
laptop_omp_particles[' elapsed/gen_count'] = laptop_omp_particles[' elapsed/gen_count']*1000

laptop_mpi_particles = pd.read_csv("Results/laptop/mpi/mpi_particles.txt")
laptop_mpi_particles[' elapsed/gen_count'] = laptop_mpi_particles[' elapsed/gen_count']*1000

laptop_ser_particles = pd.read_csv("Results/laptop/serial/ser_particles.txt")
laptop_ser_particles[' elapsed/gen_count'] = laptop_ser_particles[' elapsed/gen_count']*1000

# %%
ser_particles
# Out:
#    cores   pop_size   num_particles   final_fitness   gen_count   elapsed  \
# 0      1       2000              10    32480.000000         124     3.466
# 1      1       2000              25   126328.970111         451    82.120
# 2      1       2000              50   244152.118286         609   384.643
# 3      1       2000              75   382909.113485         805  1090.791
# 4      1       2000             100   570759.216063        1000  2395.883
# 5      1       2000             150    97266.967975         213  1236.609
# 6      1       2000             175    89034.343040         193  1546.809
# 7      1       2000             200    97320.008269         207  2115.881
# 8      1       2000             250   113839.203004          83  1322.532
# 9      1       2000             300   142782.101473         154  3432.141
#
#     elapsed/gen_count
# 0              27.954
# 1             182.083
# 2             631.597
# 3            1355.020
# 4            2395.883
# 5            5805.676
# 6            8014.556
# 7           10221.647
# 8           15934.123
# 9           22286.629

# %%
omp_particles
# Out:
#     cores   pop_size   num_particles   final_fitness   gen_count   elapsed  \
# 0      32       2000              10    48941.026234         188    18.259
# 1      32       2000              25   126274.534750         491    50.259
# 2      32       2000              50   223938.642601         416    70.570
# 3      32       2000              75   358164.339703        1000   190.807
# 4      32       2000             100   496864.920450         867   207.434
# 5      32       2000             125   627225.759613        1000   395.481
# 6      32       2000             150   593749.244292        1000   451.294
# 7      32       2000             175    93236.674824         152   112.320
# 8      32       2000             200    97207.240786          69    67.603
# 9      32       2000             250   129626.486877         183   225.456
# 10     32       2000             300   162771.945391         146   247.519
# 11     32       2000             350            -nan        1000  2164.755
# 12     32       2000             400            -nan        1000  2416.253
# 13     32       2000             500            -nan        1000  3440.660
#
#      elapsed/gen_count
# 0               97.120
# 1              102.361
# 2              169.640
# 3              190.807
# 4              239.255
# 5              395.481
# 6              451.294
# 7              738.946
# 8              979.756
# 9             1232.003
# 10            1695.338
# 11            2164.755
# 12            2416.250
# 13            3440.660

# %%
mpi_particles
# Out:
#     cores   pop_size   num_particles   migration_interval   migration_rate  \
# 0      32       2000              10                   50             0.05
# 1      32       2000              25                   50             0.05
# 2      32       2000              50                   50             0.05
# 3      32       2000              75                   50             0.05
# 4      32       2000             100                   50             0.05
# 5      32       2000             125                   50             0.05
# 6      32       2000             150                   50             0.05
# 7      32       2000             175                   50             0.05
# 8      32       2000             200                   50             0.05
# 9      32       2000             250                   50             0.05
# 10     32       2000             300                   50             0.05
# 11     32       2000             350                   50             0.05
# 12     32       2000             400                   50             0.05
# 13     32       1984             500                   50             0.05
#
#      final_fitness   gen_count   elapsed   elapsed/gen_count
# 0     40655.500288         800     1.054               1.318
# 1     93573.803575         800     5.972               7.465
# 2    130028.859854         800    29.645              37.056
# 3    268457.194536         800    81.162             101.452
# 4    300656.870291         800   114.832             143.540
# 5    382360.641129         800   158.901             198.620
# 6    410191.179570         800   226.650             283.312
# 7    499675.723484         800   299.556             374.445
# 8    540667.280965         800   378.819             473.523
# 9    662297.318437         800   614.658             768.323
# 10   576728.970615         800   859.194            1073.993
# 11   620907.837982         800  1135.729            1419.661
# 12            -nan         800  1548.892            1936.115
# 13            -nan         800  2390.220            2987.776

# %%
laptop_omp_particles
# Out:
#    cores   pop_size   num_particles   final_fitness   gen_count   elapsed  \
# 0      4       2000              10    32479.999435         108     6.254
# 1      4       2000              25   118099.165532         227    17.002
# 2      4       2000              50   227691.635610         545    66.876
# 3      4       2000              75   374840.760352         603   121.547
# 4      4       2000             100   500729.182022        1000   469.222
# 5      4       2000             125   590322.427333        1000   456.395
# 6      4       2000             150   647163.124502        1000   622.297
# 7      4       2000             175   105720.488776         221   189.561
# 8      4       2000             200   109637.993536         223   265.602
#
#     elapsed/gen_count
# 0              57.910
# 1              74.897
# 2             122.708
# 3             201.571
# 4             469.222
# 5             456.395
# 6             622.297
# 7             857.743
# 8            1191.039

# %%
laptop_mpi_particles
# Out:
#    cores   pop_size   num_particles   migration_interval   migration_rate  \
# 0      4       2000              10                   50             0.05
# 1      4       2000              25                   50             0.05
# 2      4       2000              50                   50             0.05
# 3      4       2000              75                   50             0.05
# 4      4       2000             100                   50             0.05
# 5      4       2000             125                   50             0.05
# 6      4       2000             150                   50             0.05
# 7      4       2000             175                   50             0.05
# 8      4       2000             200                   50             0.05
#
#     final_fitness   gen_count   elapsed   elapsed/gen_count
# 0    52973.082798         800     1.806               2.258
# 1   114067.577599         800    12.189              15.236
# 2   231889.055274         800    50.756              63.445
# 3   309279.527813         800   107.274             134.093
# 4   435437.406334         800   192.903             241.129
# 5   537131.993340         800   298.269             372.836
# 6   528624.682610         800   422.292             527.865
# 7   642796.115974         800   570.898             713.622
# 8   316112.168317         800   748.367             935.458

# %%
laptop_ser_particles
# Out:
#    cores   pop_size   num_particles   final_fitness   gen_count   elapsed  \
# 0      1       2000              10    44687.500288         152     1.033
# 1      1       2000              25   114067.777442         420    20.046
# 2      1       2000              50   244317.148737         497    92.525
# 3      1       2000              75   415487.046022        1000  1051.097
# 4      1       2000             100   492664.475544         795   893.834
# 5      1       2000             125   582207.170616        1000  1797.833
# 6      1       2000             150   696327.281451        1000  1717.152
#
#     elapsed/gen_count
# 0               6.799
# 1              47.729
# 2             186.168
# 3            1051.097
# 4            1124.320
# 5            1797.833
# 6            1717.152

# %%
plt.figure(figsize=(9,7))
plt.grid(alpha=0.15)
plt.minorticks_on()
plt.grid(which='minor', color='beige', alpha=0.25)
plt.plot(ser_particles[' num_particles'], ser_particles[' elapsed/gen_count'],marker='D', color="teal")
plt.plot(omp_particles[' num_particles'],omp_particles[' elapsed/gen_count'],marker='o', color="violet")
plt.plot(mpi_particles[' num_particles'],mpi_particles[' elapsed/gen_count'],marker='x', color="tab:red")
plt.legend(['serial','openmp','mpi'])
plt.ylabel('Time per 1000 generations (μs)')
plt.xlabel('Number of particles')
# Out:
# Text(0.5, 0, 'Number of particles')

# %%
plt.figure(figsize=(9,7))
plt.grid(alpha=0.15)
plt.minorticks_on()
plt.grid(which='minor', color='beige', alpha=0.25)
plt.plot(ser_particles[' num_particles'][:6], ser_particles[' elapsed/gen_count'][:6],marker='D', color="teal")
plt.plot(omp_particles[' num_particles'][:7],omp_particles[' elapsed/gen_count'][:7],marker='o', color="violet")
plt.plot(mpi_particles[' num_particles'][:7],mpi_particles[' elapsed/gen_count'][:7],marker='x', color="tab:red")

plt.plot(laptop_ser_particles[' num_particles'], laptop_ser_particles[' elapsed/gen_count'],marker='D', color="teal",dashes=[2, 2])
plt.plot(laptop_omp_particles[' num_particles'][:7],laptop_omp_particles[' elapsed/gen_count'][:7],marker='o', color="violet",dashes=[2, 2])
plt.plot(laptop_mpi_particles[' num_particles'][:7],laptop_mpi_particles[' elapsed/gen_count'][:7],marker='x', color="tab:red",dashes=[2, 2])
plt.legend(['serial (hpc)','openmp (hpc)','mpi (hpc)','serial (laptop)','openmp (laptop)','mpi (laptop)'])
plt.ylabel('Time per 1000 generations')
plt.xlabel('Number of particles')
# Out:
# Text(0.5, 0, 'Number of particles')
